# %% [markdown]
# ## ***Import Statements***

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
import scipy.cluster.hierarchy as shc
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# ## ***Loading Dataset***

# %%
data = pd.read_csv('cleaned maternal health dataset.csv')

# %%
data
# Out:
#      Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  \
# 0     25         130           80  15.0      98.0         86
# 1     35         140           90  13.0      98.0         70
# 2     29          90           70   8.0     100.0         80
# 3     30         140           85   7.0      98.0         70
# 4     35         120           60   6.1      98.0         76
# ..   ...         ...          ...   ...       ...        ...
# 447   12         100           50   6.4      98.0         70
# 448   15         100           60   6.0      98.0         80
# 449   15         100           49   7.6      98.0         77
# 450   12         100           50   6.0      98.0         70
# 451   21         100           50   6.8      98.0         60
#
#      RiskLevel_Encoded
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    3
# ..                 ...
# 447                  2
# 448                  3
# ...

# %%
drop = ['HeartRate', 'RiskLevel_Encoded']
data = data.drop(drop, axis=1)

# %%
data.describe()
# Out:
#               Age  SystolicBP  DiastolicBP          BS    BodyTemp
# count  452.000000  452.000000   452.000000  452.000000  452.000000
# mean    29.194690  110.553097    75.418142    8.346173   98.692478
# std     13.767379   17.872282    13.754578    2.829209    1.410897
# min     10.000000   70.000000    49.000000    6.000000   98.000000
# 25%     19.000000   90.000000    65.000000    6.900000   98.000000
# 50%     25.000000  120.000000    80.000000    7.500000   98.000000
# 75%     35.000000  120.000000    86.000000    7.900000   98.000000
# max     70.000000  160.000000   100.000000   19.000000  103.000000

# %% [markdown]
# ## ***Data Visualization***

# %%
sns.pairplot(data)
# Out:
# /home/oem/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/oem/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/oem/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# - We keep all features since there are visible clusters in all of them

# %% [markdown]
# ## ***Scaling Features***

# %%
scaling=StandardScaler()
scaled=scaling.fit_transform(data)

# %%
scaled_data=pd.DataFrame(scaled,columns=data.columns)
scaled_data.head()
# Out:
#         Age  SystolicBP  DiastolicBP        BS  BodyTemp
# 0 -0.305021    1.089310     0.333484  2.354439 -0.491351
# 1  0.422139    1.649455     1.061321  1.646744 -0.491351
# 2 -0.014157   -1.151273    -0.394352 -0.122492  0.927758
# 3  0.058559    1.649455     0.697402 -0.476340 -0.491351
# 4  0.422139    0.529164    -1.122188 -0.794802 -0.491351

# %% [markdown]
# ## ***Hierarchical Clustering using a Dendrogram***

# %%
plt.figure(figsize=(10, 7))
plt.title("Dendrogram")

# Perform hierarchical clustering and create a dendrogram
clusters = shc.linkage(scaled_data, method='ward', metric='euclidean')
shc.dendrogram(clusters)
plt.axhline(y=12, color='r', linestyle='--')
plt.show()

# %% [markdown]
# - Drew the horizontal line where the distance between clustering starts to get big
# - Total of 13 clusters

# %% [markdown]
# ## ***Calculting distance between clusters and linking them using Euclidean distance and Ward Linkage***

# %%
clusters = 6
clustering_model = AgglomerativeClustering(n_clusters=clusters, linkage='ward', metric='euclidean')
cluster_labels = clustering_model.fit_predict(scaled_data)

# %% [markdown]
# ## ***Cluster Characteristics Analysis***

# %%
data['Cluster'] = cluster_labels

cluster_means = data.groupby('Cluster').mean()
print(cluster_means)
# Out:
#                Age  SystolicBP  DiastolicBP         BS    BodyTemp
# Cluster
# 0        41.218182  114.672727    76.318182   7.349182   98.021818
# 1        21.936364  120.090909    85.872727   7.310364   98.009091
# 2        44.563636  129.000000    87.363636  15.072727   98.101818
# 3        19.097826   89.923913    59.565217   7.027283   98.076087
# 4        31.051282  120.384615    79.487179   7.964359  101.410256
# 5        18.043478   88.760870    62.239130   8.126087  101.565217

# %% [markdown]
# - Normal blood pressure - systolic<120 and diastolic<80
#
# - Cluster 0 - middle aged women with normal blood pressure, blood sugar is the average compared to others, normal body temperature
# - Cluster 1 - very young women with high blood pressure, average blood sugar level and normal body temperature
# - Cluster 2 - middle aged women with high blood pressure, high blood sigar levels and normal body temperature
# - Cluster 3 - very young women with normal blood pressure, average blood sugar level and normal body temperature
# - Cluster 4 - young women with normal blood pressure, average blood sugar level and high body temperature
# - Cluster 5 - very young women with normal blood pressure, slighlty higher blood sugar level and high body temperature
